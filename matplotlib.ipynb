# %%
#why do we need visualisation? summarisation of data
#matplotlib, seaborn, plotly, bokeh
#matplotlib>> Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#bar, hist, scatter plot, pie chart, line

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.08053723, 0.87822672, 0.97393004, 0.23192609, 0.73592932,
#        0.46909796, 0.04217162, 0.19480006, 0.09948952, 0.98070255,
#        0.0889523 , 0.84884699, 0.53730232, 0.18710769, 0.59256719,
#        0.56353019, 0.79794005, 0.26953046, 0.89597157, 0.02964675,
#        0.57521165, 0.81996671, 0.21389431, 0.73827733, 0.41186617,
#        0.32352624, 0.27544136, 0.11683324, 0.84943075, 0.88305088,
#        0.99058802, 0.60602616, 0.71376111, 0.51706664, 0.86403262,
#        0.50409247, 0.72921299, 0.66804209, 0.29985833, 0.08333973,
#        0.55230809, 0.3553642 , 0.4472271 , 0.5543186 , 0.17850346,
#        0.77473257, 0.90621279, 0.25868036, 0.17256568, 0.67742208])

# %%
y
# Out:
# array([0.9556836 , 0.34263798, 0.03068157, 0.97234055, 0.00133377,
#        0.78002799, 0.82098783, 0.47142098, 0.24958192, 0.81547015,
#        0.50190449, 0.50779378, 0.11689444, 0.14033108, 0.14395529,
#        0.58444375, 0.7853349 , 0.6438759 , 0.32546204, 0.42959155,
#        0.84413588, 0.68952716, 0.6871214 , 0.08454596, 0.24889134,
#        0.20727691, 0.01211197, 0.57936206, 0.64423194, 0.58198379,
#        0.26723707, 0.58672496, 0.90629151, 0.5173162 , 0.18906883,
#        0.4443059 , 0.93714033, 0.88363721, 0.94878189, 0.81742154,
#        0.73210613, 0.29886035, 0.08177375, 0.12536551, 0.79320046,
#        0.74723426, 0.1962322 , 0.05833983, 0.76942646, 0.78575037])

# %%
plt.scatter(x,y) #To understand the relationship between two variables

# %%
df = pd.DataFrame(np.random.randn(1000),columns = ['data'],index = pd.date_range('2024-03-29',periods=1000))

# %%
df
# Out:
#                 data
# 2024-03-29 -0.193063
# 2024-03-30  0.431057
# 2024-03-31 -0.661605
# 2024-04-01 -1.113336
# 2024-04-02  1.963621
# ...              ...
# 2026-12-19  1.647150
# 2026-12-20  0.190715
# 2026-12-21  1.701729
# 2026-12-22 -0.882529
# 2026-12-23 -1.211458
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,9))
# Out:
# <Axes: >

# %%
#line plot
#whenever time component is involved on x axis
#depict the relation between two variables in the trend


x = [1, 2, 3, 4, 5]
y = [5, 1, 7, 8, 2]

plt.plot(x, y)

# %%
plt.plot(x, y)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red")
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o")
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--')
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 3)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 3, markersize=10)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 3, markersize=10)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]


plt.plot(x, y1, color = "red", marker = "o", linestyle = '--', linewidth = 3, markersize=6, label = 'line y1')
plt.plot(x, y2, color = "b", marker = "o", linestyle = '--', linewidth = 3, markersize=10, label = 'line y2')

plt.xlabel("x data axis")
plt.ylabel("y data axis")

plt.title("Multiple lines in one plot")
plt.legend()

plt.show()

# %%
x = np.linspace(0, 10, 100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
plt.plot(x , np.sin(x))
plt.plot(x , np.cos(x))

# %%
plt.plot(x, np.sin(x), ':')

# %%
plt.plot(x, np.sin(x), '--')

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), '-')

# %%
plt.figure()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x),color = 'red')

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))

plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))

plt.subplot(2, 2, 4)
plt.plot(x, np.cos(x+1))

plt.show()

# %%
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))


plt.show()

# %%
plt.plot(x, np.sin(x-0), color = "blue")

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)

plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.axis('equal')
plt.grid()
plt.show()

# %%
#histogram>> continuous/numerical data distribution
data =  np.random.randn(1000)
plt.hist(data, color = 'red', bins =20)
plt.show()

# %%
data = np.random.randn(2000)
plt.hist(data, color ='lightgreen', bins = 30)
plt.show()

# %%
#stacked histogram


data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
data1
# Out:
# array([-1.21652885,  1.81950823,  0.40681358, ...,  0.05779837,
#        -0.51682408,  0.61123124])

# %%
data2
# Out:
# array([ 1.36483273,  5.94649239,  3.4748431 , ..., -1.60512691,
#         2.65317645,  2.05618637])

# %%
plt.hist([data1, data2], bins = 20, color = ['r', 'b'], label = ['dist1', 'dist2'])
plt.xlabel('Values')
plt.ylabel('frequency')
plt.title("stacked histogram")
plt.show()

# %%
#scatter plot >> to understand the relationship between two features

x = np.random.rand(50)
y = np.random.rand(50)

x
# Out:
# array([0.78735297, 0.75555418, 0.98918151, 0.92529198, 0.17122364,
#        0.03276347, 0.80778403, 0.67156503, 0.49259678, 0.99098147,
#        0.66642326, 0.31515848, 0.31459029, 0.38773603, 0.231803  ,
#        0.92220038, 0.15938585, 0.77675818, 0.78854101, 0.64582984,
#        0.24957863, 0.70642726, 0.03850081, 0.29631548, 0.90769932,
#        0.31353971, 0.35123182, 0.50021296, 0.14025885, 0.84115404,
#        0.7446906 , 0.2041226 , 0.07620628, 0.723382  , 0.36452571,
#        0.22824054, 0.67124725, 0.79564801, 0.83207592, 0.05040856,
#        0.31498409, 0.6548775 , 0.9048626 , 0.66463218, 0.71898139,
#        0.48188485, 0.18648892, 0.41265223, 0.12518022, 0.09006852])

# %%
y
# Out:
# array([0.72160372, 0.28691459, 0.33097266, 0.34734595, 0.55629447,
#        0.73054677, 0.0550654 , 0.4933877 , 0.45762675, 0.87465358,
#        0.78361504, 0.74735642, 0.54402391, 0.61991179, 0.57368832,
#        0.10475738, 0.56426452, 0.31172179, 0.39906647, 0.7807141 ,
#        0.70143574, 0.73687001, 0.62954006, 0.97068997, 0.65155574,
#        0.61529085, 0.38379768, 0.01441468, 0.22911849, 0.52727383,
#        0.3400715 , 0.58641745, 0.65841679, 0.10990176, 0.51913363,
#        0.00318913, 0.86067091, 0.28759141, 0.40181274, 0.92401955,
#        0.14502809, 0.45199027, 0.67942342, 0.90362521, 0.09525282,
#        0.11623434, 0.15588551, 0.91857   , 0.03849192, 0.76417607])

# %%
plt.scatter(x, y, c = 'r', marker = 'X')

# %%
#bar plot >> To see the distribution of categorical variables
x = ['a', 'b', 'c', 'd']
y = [4, 6, 1, 2]
plt.bar(x,y, color ='r')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x, y, color = 'r')
# Out:
# <BarContainer object of 4 artists>

# %%
#pie chart >> To understand the percnt dist of data
langs = ['c', 'python','java']
students = [20,30,40]
plt.pie(students,labels = langs , autopct='%1.1f%%')
plt.title('pie plot')
plt.show()

# %%
langs = ['vidhi singh','anurag singh','sirsa farm']
students = [20,10,5]
plt.pie(students,labels = langs , autopct='%1.1f%%')
plt.title("pie chart")
plt.show()

# %%
explode = [0.0,0.1,0.1]
langs = ['C', 'Python', 'Java']
students = [20, 100, 40]


plt.pie(students, labels = langs, autopct = '%1.1f%%', explode = explode, shadow = True)
plt.title("anurag singh")
plt.show()

# %%
#3d plot

x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection =  '3d')


ax.scatter(x,y,z, c = 'red')

# %%
#3d plot

x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z,c='red')

# %%
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z,c = 'red')

# %%
data = pd.read_csv("/content/Bank_churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
plt.scatter(x = data['Age'], y=data['Balance'])

# %%
data.plot.scatter(x = 'Age', y = 'Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'], color='red')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Balance'], color='red')
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
data.boxplot(column='Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x7dbb21e51350>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7dbb20ce1a10>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7dbb20880d90>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7dbb20882510>}

# %%
plt.violinplot(data['Age'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x7dbb20dfa0d0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7dbb223e5690>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7dbb207300d0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7dbb206a0d10>}

# %%
import matplotlib.pyplot as plt

# Sample data
years = [2021, 2018, 2022, 2023, 2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]

# Create a area plot
plt.stackplot(years, category1, category2, category3, labels=['Category 1', 'Category 2', 'Category 3'],
              colors=['skyblue', 'lightgreen', 'orange'])

# Add labels and title
plt.xlabel("Years")
plt.ylabel("Values")
plt.title("Area Plot")
plt.legend()

plt.show()

# %%
# revision
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.63678089, 0.92590891, 0.43681089, 0.87102732, 0.40805427,
#        0.77918649, 0.30520516, 0.01467876, 0.03496942, 0.93395127,
#        0.77548774, 0.13659051, 0.79050719, 0.88048522, 0.45925606,
#        0.5693914 , 0.549001  , 0.89306897, 0.36751524, 0.03289497,
#        0.22444922, 0.27722947, 0.98382131, 0.37713095, 0.56270346,
#        0.92142982, 0.03725744, 0.73501256, 0.63639258, 0.65775062,
#        0.25610614, 0.35648851, 0.03993894, 0.15295491, 0.17319246,
#        0.61393074, 0.421037  , 0.47568435, 0.22804892, 0.73403043,
#        0.72387144, 0.46480948, 0.1231251 , 0.30145379, 0.0394406 ,
#        0.45692428, 0.35522621, 0.14028613, 0.84427557, 0.51462977])

# %%
y
# Out:
# array([0.24046121, 0.51879027, 0.57093307, 0.6337568 , 0.00296113,
#        0.1725881 , 0.4459522 , 0.72812758, 0.49659949, 0.878523  ,
#        0.67007666, 0.55385871, 0.20345193, 0.96561354, 0.40221339,
#        0.42313928, 0.68793465, 0.94587179, 0.6314105 , 0.16351374,
#        0.97681088, 0.38293997, 0.9043568 , 0.72448992, 0.67085552,
#        0.82695315, 0.73788026, 0.12561415, 0.16296073, 0.72986196,
#        0.52310924, 0.88410403, 0.93936125, 0.51143014, 0.91772045,
#        0.86719239, 0.72209026, 0.14836055, 0.30077555, 0.91925377,
#        0.44779013, 0.32501857, 0.12396757, 0.90029227, 0.23052387,
#        0.01984333, 0.45144903, 0.01594107, 0.51814726, 0.13106614])

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y , c = '#223BDC',alpha=.9,marker='X')
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("this is my x vs y")
plt.grid()

# %%
x = np.linspace(1,10 , 100)
y = np.sin(x)

# %%
x
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
#         6.90909091,  7.        ,  7.09090909,  7.18181818,  7.27272727,
#         7.36363636,  7.45454545,  7.54545455,  7.63636364,  7.72727273,
#         7.81818182,  7.90909091,  8.        ,  8.09090909,  8.18181818,
#         8.27272727,  8.36363636,  8.45454545,  8.54545455,  8.63636364,
#         8.72727273,  8.81818182,  8.90909091,  9.        ,  9.09090909,
#         9.18181818,  9.27272727,  9.36363636,  9.45454545,  9.54545455,
#         9.63636364,  9.72727273,  9.81818182,  9.90909091, 10.        ])

# %%
y
# Out:
# array([ 0.84147098,  0.88704699,  0.92529707,  0.95590534,  0.978619  ,
#         0.99325047,  0.99967891,  0.99785123,  0.98778253,  0.96955595,
#         0.94332203,  0.90929743,  0.86776314,  0.8190622 ,  0.76359681,
#         0.70182505,  0.63425707,  0.56145091,  0.48400786,  0.40256749,
#         0.31780241,  0.23041267,  0.14112001,  0.05066187, -0.04021468,
#        -0.1307591 , -0.22022362, -0.30786935, -0.39297247, -0.47483011,
#        -0.55276624, -0.6261372 , -0.69433703, -0.7568025 , -0.8130177 ,
#        -0.86251837, -0.9048957 , -0.93979971, -0.96694212, -0.98609877,
#        -0.99711147, -0.99988924, -0.99440916, -0.98071647, -0.95892427,
#        -0.92921254, -0.89182665, -0.84707537, -0.79532828, -0.73701276,
#        -0.67261042, -0.60265314, -0.52771868, -0.44842592, -0.36542971,
#        -0.2794155 , -0.19109366, -0.10119362, -0.01045784,  0.0803643 ,
#         0.17052273,  0.25927286,  0.34588171,  0.429634  ,  0.50983804,
#         0.58583144,  0.6569866 ,  0.72271585,  0.78247636,  0.83577457,
#         0.88217031,  0.92128041,  0.95278186,  0.9764145 ,  0.99198316,
#         0.99935926,  0.99848187,  0.98935825,  0.97206374,  0.94674118,
#         0.9135997 ,  0.87291301,  0.82501713,  0.77030762,  0.70923631,
#         0.64230758,  0.57007418,  0.49313267,  0.41211849,  0.32770071,
#         0.24057653,  0.15146548,  0.06110351, -0.0297631 , -0.1203839 ,
#        -0.21001048, -0.29790263, -0.38333447, -0.46560043, -0.54402111])

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(8,2))
plt.plot(x,y , '--r')
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.title("this is my sin wave graph")
plt.grid()

# %%
x = ['a', 'b' , 'c','d','e']
y = np.random.rand(5)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y
# Out:
# array([0.80737212, 0.66565141, 0.12156467, 0.65981877, 0.90368735])

# %%
plt.figure(figsize=(5,3))
plt.bar(x,y,color = '#7E10D5')
plt.xlabel("representing my cat data")
plt.ylabel("representing my num data")
plt.title("this is my bar plot")
plt.grid()

# %%
plt.figure(figsize=(5,3))
plt.barh(x,y,color = '#7E10D5')
plt.xlabel("representing my cat data")
plt.ylabel("representing my num data")
plt.title("this is my bar plot")
plt.grid()

# %%
x = [3,4,5,6,7,8]
y = [4,5,6,7,8,9]

# %%
plt.figure(figsize=(6,2))
plt.plot(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y)

# %%
data = [1,2,3,4,5,6,5,6,6,7,7,8,8,8,8,8]

# %%
plt.figure(figsize=(6,3))
plt.hist(data,color="#700EBE")
plt.xlabel("representing uniqe val")
plt.ylabel("representing feq")
plt.title("Hist plot example")
plt.grid()
plt.savefig("test.png")

# %%
plt.figure(figsize=(6,3))
plt.hist(data,color="#700EBE")
plt.xlabel("representing uniqe val")
plt.ylabel("representing feq")
plt.title("Hist plot example")
plt.grid()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z,c='#9327E8')
plt.xlabel("my x axis")
plt.ylabel("my y axis")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z,c='#9327E8', alpha=.12)
